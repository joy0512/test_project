# %% [markdown]
# <a href="https://colab.research.google.com/github/joy0512/test_project/blob/main/Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from matplotlib import pyplot as plt

### Tensorflow 2.0 ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import Input
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import regularizers
from tensorflow.keras import utils

# %%
# 아래 있는 model의 plot을 보고 그대로 CNN 모델을 구현하시오
# Hint : 각 layer에서 사용된 이름이 좌측에 적혀있습니다.
#        오른쪽의 2개는 순서대로 input과 ouput의 shape입니다.
# 모델을 구현한 후에 model.summary() 를 써서 맨 아래 있는 것처럼 출력되도록 하시오.
model = Sequential()
model.add(Input(shape=(128, 128, 1)))
model.add(layers.Conv2D(16, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Conv2D(64, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='sigmoid'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(5, activation='sigmoid'))

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 128, 128, 16)      160
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# ...
# Total params: 2,121,221
# Trainable params: 2,121,221
# Non-trainable params: 0
# _________________________________________________________________
